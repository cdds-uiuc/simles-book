# %%
import numpy as np
import pandas as pd
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %%
def norm(x):
    return (x-np.mean(x))/np.std(x)

n_samples=5000

t=np.arange(n_samples)
x1=stats.norm.rvs(loc=0,scale=1,size=n_samples)
x2=stats.norm.rvs(loc=0,scale=1,size=n_samples)
x3=stats.norm.rvs(loc=0,scale=1,size=n_samples)
y=x1*x2*x3

X=np.stack([norm(x1),norm(x2),norm(x3)],axis=1);

# %%
fig,ax=plt.subplots(2,2,figsize=[20,12])
ax[0,0].plot(t,norm(x1)-5,label='$x_1$')
ax[0,0].plot(t,norm(x2)-10,label='$x_2$')
ax[0,0].plot(t,norm(x3)-15,label='$x_3$')
ax[0,0].plot(t,norm(y),linewidth=2,label='$y$')
ax[0,0].legend(ncol=4)
ax[0,0].set_xlim(0,200)


ax[0,1].plot(x1,norm(y),'o')

ax[1,0].plot(x2,norm(y),'o')
ax[1,1].plot(x3,norm(y),'o')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression().fit(Xn,yn)

yhat_train_0=lin_reg.predict(X_train);
yhat_test_0=lin_reg.predict(X_test);


from sklearn.neural_network import MLPRegressor

model_1 = MLPRegressor(hidden_layer_sizes=5,max_iter=5000)
model_2 = MLPRegressor(hidden_layer_sizes=16,max_iter=5000)
model_3 = MLPRegressor(hidden_layer_sizes=[64,64],max_iter=500)


mlp_1=model_1.fit(X_train, y_train)
mlp_2=model_2.fit(X_train, y_train)
mlp_3=model_3.fit(X_train, y_train)

yhat_train_1=mlp_1.predict(X_train);
yhat_train_2=mlp_2.predict(X_train);
yhat_train_3=mlp_3.predict(X_train);


yhat_test_1=mlp_1.predict(X_test);
yhat_test_2=mlp_2.predict(X_test);
yhat_test_3=mlp_3.predict(X_test);

# %%
fig,ax=plt.subplots(2,4,figsize=[20,12])

for i in [0,1]:
    for j in [0,1,2,3]:
        ax[i,j].plot([np.min(yn),np.max(yn)],[np.min(yn),np.max(yn)],'k-')
        ax[i,j].set_xlabel('$y$')

ax[0,0].set_ylabel('$\hat y$')        

ax[0,0].plot(y_train,yhat_train_0,'r.')
ax[0,1].plot(y_train,yhat_train_1,'r.')
ax[0,2].plot(y_train,yhat_train_2,'r.')
ax[0,3].plot(y_train,yhat_train_3,'r.')

ax[1,0].plot(y_test,yhat_test_0,'r.')
ax[1,1].plot(y_test,yhat_test_1,'r.')
ax[1,2].plot(y_test,yhat_test_2,'r.')
ax[1,3].plot(y_test,yhat_test_3,'r.')

# %%
mlp_3.get_params()
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': [64, 64],
#  'learning_rate': 'constant',
#  'learning_rate_init': 0.001,
#  'max_fun': 15000,
#  'max_iter': 200,
#  'momentum': 0.9,
#  'n_iter_no_change': 10,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': None,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
mlp_1.intercepts_
# Out:
# [array([-0.12446811, -0.49202429,  0.71787913, -0.87707703, -0.52816551]),
#  array([-0.05964043])]

# %%
mlp_1.coefs_
# Out:
# [array([[ 0.82800314,  1.66394691, -0.72815217,  0.35247481],
#         [ 0.18500211,  0.08261293,  0.26185878, -0.05410589],
#         [-0.83928655,  1.5357392 ,  0.8822249 ,  0.44946345]]),
#  array([[-1.34872164],
#         [ 0.98751301],
#         [-1.50626438],
#         [-1.73946699]])]

# %%
mlp_1.n_features_in_
# Out:
# 4

# %%
import numpy as np
x=np.linspace(-20,20,100)
y=np.sinc(x)
plt.plot(x,y)

# %%
def norm(x):
    return (x-np.mean(x))/np.std(x)


n_samples=100000
x=stats.uniform.rvs(loc=-5,scale=10,size=n_samples)
y=np.sin(x*2)
X=x.reshape(-1,1)
plt.plot(X,y,'.')

# %%
from sklearn.neural_network import MLPRegressor
model = MLPRegressor(hidden_layer_sizes=[64,64,64],max_iter=5000)
mlp   =model.fit(X,y)
yhat  =model.predict(X)

# %%
x1=np.linspace(-5,5,200).reshape(-1,1)
x2=np.linspace(-7,7,1000).reshape(-1,1)
y1=model.predict(x1)
y2=model.predict(x2)

# %%
fig,ax=plt.subplots(1,figsize=[12,6])
plt.plot(x,y,'ok',label='training data')
plt.plot(x2,y2,'r-',linewidth=3,label='Neural Net')    
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

# %%
from sklearn.neural_network import MLPRegressor

mlp_obj_1 = MLPRegressor(hidden_layer_sizes=5,max_iter=5000)
mlp_obj_2= MLPRegressor(hidden_layer_sizes=16,max_iter=5000)
mlp_obj_3= MLPRegressor(hidden_layer_sizes=[128],max_iter=5000)


mlp_1=mlp_obj_1.fit(X_train, y_train)
mlp_2=mlp_obj_2.fit(X_train, y_train)
mlp_3=mlp_obj_3.fit(X_train, y_train)

yhat_train_1=mlp_1.predict(X_train);
yhat_train_2=mlp_2.predict(X_train);
yhat_train_3=mlp_3.predict(X_train);


yhat_test_1=mlp_1.predict(X_test);
yhat_test_2=mlp_2.predict(X_test);
yhat_test_3=mlp_3.predict(X_test);

# %%
fig,ax=plt.subplots(1,3,figsize=[18,6])


for j in [0,1,2]:
        ax[j].plot([np.min(yn),np.max(yn)],[np.min(yn),np.max(yn)],'k--')
        ax[j].set_xlabel('$y$')
        ax[j].set_xlim(-5,5)
        ax[j].set_ylim(-5,5)

ax[0].set_ylabel(r'$\hat y$')     


ax[0].plot(y_train,yhat_train_1,'r.')
ax[0].set_title('ANN 5 hidden layers')

ax[1].plot(y_train,yhat_train_2,'r.')
ax[1].set_title('ANN 16 hidden layers')

ax[2].plot(y_train,yhat_train_3,'r.')
ax[2].set_title('ANN 128 hidden layers')
# Out:
# Text(0.5, 1.0, 'ANN 128 hidden layers')

# %%
fig,ax=plt.subplots(1,3,figsize=[18,6])


for j in [0,1,2]:
        ax[j].plot([np.min(yn),np.max(yn)],[np.min(yn),np.max(yn)],'k--')
        ax[j].set_xlabel('$y$')
        ax[j].set_xlim(-5,5)
        ax[j].set_ylim(-5,5)

ax[0].set_ylabel(r'$\hat y$')     


ax[0].plot(y_test,yhat_test_1,'r.')
ax[0].set_title('ANN 5 hidden layers')

ax[1].plot(y_test,yhat_test_2,'r.')
ax[1].set_title('ANN 16 hidden layers')

ax[2].plot(y_train,yhat_train_3,'r.')
ax[2].set_title('ANN 128 hidden layers')
# Out:
# Text(0.5, 1.0, 'ANN 128 hidden layers')

# %%
fig,ax=plt.subplots(2,2,figsize=[12,12])

for i in [0,1]:
    for j in [0,1]:
        ax[i,j].plot([np.min(yn),np.max(yn)],[np.min(yn),np.max(yn)],'k--')

        ax[i,j].set_xticks(np.arange(-6,8,3))
        ax[i,j].set_yticks(np.arange(-6,8,3))

ax[0,0].set_ylabel('$\hat y$')  
ax[1,0].set_ylabel('$\hat y$')  
ax[1,0].set_xlabel('$y$')
ax[1,1].set_xlabel('$y$')

ax[0,0].plot(y_train,yhat_train_0,'r.')
ax[0,1].plot(y_train,yhat_train_1,'r.')
ax[1,0].plot(y_train,yhat_train_2,'r.')
ax[1,1].plot(y_train,yhat_train_3,'r.')

ax[0,0].set_title('Linear Regression',fontsize=20)
ax[0,1].set_title('ANN 4 hidden layers',fontsize=20)
ax[1,0].set_title('ANN 32 hidden layers',fontsize=20)
ax[1,1].set_title('ANN 128 hidden layers',fontsize=20)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\h'
# <>:11: SyntaxWarning: invalid escape sequence '\h'
# <>:10: SyntaxWarning: invalid escape sequence '\h'
# <>:11: SyntaxWarning: invalid escape sequence '\h'
# /var/folders/pr/3_264g5j1d15jdsjfgsqbdj80000gp/T/ipykernel_2947/4262956793.py:10: SyntaxWarning: invalid escape sequence '\h'
#   ax[0,0].set_ylabel('$\hat y$')
# /var/folders/pr/3_264g5j1d15jdsjfgsqbdj80000gp/T/ipykernel_2947/4262956793.py:11: SyntaxWarning: invalid escape sequence '\h'
#   ax[1,0].set_ylabel('$\hat y$')
# Text(0.5, 1.0, 'ANN 128 hidden layers')

# %%
fig,ax=plt.subplots(2,4,figsize=[20,12])

for i in [0,1]:
    for j in [0,1,2,3]:
        ax[i,j].plot([np.min(y),np.max(y)],[np.min(y),np.max(y)],'k-')
        ax[i,j].set_xlabel('$y$')

ax[0,0].set_ylabel('$\hat y$')        

ax[0,0].plot(y_train,yhat_train_0,'r.')
ax[0,1].plot(y_train,yhat_train_1,'r.')
ax[0,2].plot(y_train,yhat_train_2,'r.')
ax[0,3].plot(y_train,yhat_train_3,'r.')

ax[1,0].plot(y_test,yhat_test_0,'r.')
ax[1,1].plot(y_test,yhat_test_1,'r.')
ax[1,2].plot(y_test,yhat_test_2,'r.')
ax[1,3].plot(y_test,yhat_test_3,'r.')

# %%
mlp_3.get_params()
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': [126],
#  'learning_rate': 'constant',
#  'learning_rate_init': 0.001,
#  'max_fun': 15000,
#  'max_iter': 5000,
#  'momentum': 0.9,
#  'n_iter_no_change': 10,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': None,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
mlp_1.intercepts_
# Out:
# [array([ 0.90196902, -0.79492916,  0.62385082,  1.29861309,  1.51917621]),
#  array([-0.70604129])]

# %%
mlp_1.coefs_

# %%
mlp_1.n_features_in_

# %%
import numpy as np
x=np.linspace(-20,20,100)
y=np.sinc(x)
plt.plot(x,y)

# %%
def norm(x):
    return (x-np.mean(x))/np.std(x)


n_samples=100000
x=stats.uniform.rvs(loc=-5,scale=10,size=n_samples)
y=np.sin(x*2)
X=x.reshape(-1,1)
plt.plot(X,y,'.')

# %%
from sklearn.neural_network import MLPRegressor
model = MLPRegressor(hidden_layer_sizes=[64,64,64],max_iter=5000)
mlp   =model.fit(X,y)
yhat  =model.predict(X)

# %%
x1=np.linspace(-5,5,200).reshape(-1,1)
x2=np.linspace(-7,7,1000).reshape(-1,1)
y1=model.predict(x1)
y2=model.predict(x2)

# %%
fig,ax=plt.subplots(1,figsize=[12,6])
plt.plot(x,y,'ok',label='training data')
plt.plot(x2,y2,'r-',linewidth=3,label='Neural Net')    
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

# %%
fig,ax=plt.subplots(1,3,figsize=[18,6])


for j in [0,1,2]:
        ax[j].plot([np.min(yn),np.max(yn)],[np.min(yn),np.max(yn)],'k--')
        ax[j].set_xlabel('$y$')
        ax[j].set_xlim(-5,5)
        ax[j].set_ylim(-5,5)

ax[0].set_ylabel(r'$\hat y$')     


ax[0].plot(y_train,yhat_train_1,'r.')
ax[0].set_title('ANN 5 hidden layers')

ax[1].plot(y_train,yhat_train_2,'r.')
ax[1].set_title('ANN 16 hidden layers')

ax[2].plot(y_train,yhat_train_3,'r.')
ax[2].set_title('ANN 128 hidden layers')
# Out:
# Text(0.5, 1.0, 'ANN 128 hidden layers')

# %%
fig,ax=plt.subplots(1,3,figsize=[18,6])


for j in [0,1,2]:
        ax[j].plot([np.min(yn),np.max(yn)],[np.min(yn),np.max(yn)],'k--')
        ax[j].set_xlabel('$y$')
        ax[j].set_xlim(-5,5)
        ax[j].set_ylim(-5,5)

ax[0].set_ylabel(r'$\hat y$')     


ax[0].plot(y_test,yhat_test_1,'r.')
ax[0].set_title('ANN 5 hidden layers')

ax[1].plot(y_test,yhat_test_2,'r.')
ax[1].set_title('ANN 16 hidden layers')

ax[2].plot(y_train,yhat_train_3,'r.')
ax[2].set_title('ANN 128 hidden layers')
# Out:
# Text(0.5, 1.0, 'ANN 128 hidden layers')

# %%
fig,ax=plt.subplots(2,2,figsize=[12,12])

for i in [0,1]:
    for j in [0,1]:
        ax[i,j].plot([np.min(yn),np.max(yn)],[np.min(yn),np.max(yn)],'k--')

        ax[i,j].set_xticks(np.arange(-6,8,3))
        ax[i,j].set_yticks(np.arange(-6,8,3))

ax[0,0].set_ylabel('$\hat y$')  
ax[1,0].set_ylabel('$\hat y$')  
ax[1,0].set_xlabel('$y$')
ax[1,1].set_xlabel('$y$')

ax[0,0].plot(y_train,yhat_train_0,'r.')
ax[0,1].plot(y_train,yhat_train_1,'r.')
ax[1,0].plot(y_train,yhat_train_2,'r.')
ax[1,1].plot(y_train,yhat_train_3,'r.')

ax[0,0].set_title('Linear Regression',fontsize=20)
ax[0,1].set_title('ANN 4 hidden layers',fontsize=20)
ax[1,0].set_title('ANN 32 hidden layers',fontsize=20)
ax[1,1].set_title('ANN 128 hidden layers',fontsize=20)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\h'
# <>:11: SyntaxWarning: invalid escape sequence '\h'
# <>:10: SyntaxWarning: invalid escape sequence '\h'
# <>:11: SyntaxWarning: invalid escape sequence '\h'
# /var/folders/pr/3_264g5j1d15jdsjfgsqbdj80000gp/T/ipykernel_2947/4262956793.py:10: SyntaxWarning: invalid escape sequence '\h'
#   ax[0,0].set_ylabel('$\hat y$')
# /var/folders/pr/3_264g5j1d15jdsjfgsqbdj80000gp/T/ipykernel_2947/4262956793.py:11: SyntaxWarning: invalid escape sequence '\h'
#   ax[1,0].set_ylabel('$\hat y$')
# Text(0.5, 1.0, 'ANN 128 hidden layers')

# %%
fig,ax=plt.subplots(2,4,figsize=[20,12])

for i in [0,1]:
    for j in [0,1,2,3]:
        ax[i,j].plot([np.min(y),np.max(y)],[np.min(y),np.max(y)],'k-')
        ax[i,j].set_xlabel('$y$')

ax[0,0].set_ylabel('$\hat y$')        

ax[0,0].plot(y_train,yhat_train_0,'r.')
ax[0,1].plot(y_train,yhat_train_1,'r.')
ax[0,2].plot(y_train,yhat_train_2,'r.')
ax[0,3].plot(y_train,yhat_train_3,'r.')

ax[1,0].plot(y_test,yhat_test_0,'r.')
ax[1,1].plot(y_test,yhat_test_1,'r.')
ax[1,2].plot(y_test,yhat_test_2,'r.')
ax[1,3].plot(y_test,yhat_test_3,'r.')

# %%
mlp_3.get_params()
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': [126],
#  'learning_rate': 'constant',
#  'learning_rate_init': 0.001,
#  'max_fun': 15000,
#  'max_iter': 5000,
#  'momentum': 0.9,
#  'n_iter_no_change': 10,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': None,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
mlp_1.intercepts_
# Out:
# [array([ 0.90196902, -0.79492916,  0.62385082,  1.29861309,  1.51917621]),
#  array([-0.70604129])]

# %%
mlp_1.coefs_

# %%
mlp_1.n_features_in_

# %%
import numpy as np
x=np.linspace(-20,20,100)
y=np.sinc(x)
plt.plot(x,y)

# %%
def norm(x):
    return (x-np.mean(x))/np.std(x)


n_samples=100000
x=stats.uniform.rvs(loc=-5,scale=10,size=n_samples)
y=np.sin(x*2)
X=x.reshape(-1,1)
plt.plot(X,y,'.')

# %%
from sklearn.neural_network import MLPRegressor
model = MLPRegressor(hidden_layer_sizes=[64,64,64],max_iter=5000)
mlp   =model.fit(X,y)
yhat  =model.predict(X)

# %%
x1=np.linspace(-5,5,200).reshape(-1,1)
x2=np.linspace(-7,7,1000).reshape(-1,1)
y1=model.predict(x1)
y2=model.predict(x2)

# %%
fig,ax=plt.subplots(1,figsize=[12,6])
plt.plot(x,y,'ok',label='training data')
plt.plot(x2,y2,'r-',linewidth=3,label='Neural Net')    
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

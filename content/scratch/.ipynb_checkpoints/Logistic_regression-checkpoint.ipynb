# %% [markdown]
# # Logistic Regression

# %%
import numpy as np
import pandas as pd
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 16,8
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
          'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
def logit(x,beta):
    return np.exp(beta[0]+x*beta[1])/(1+np.exp(beta[0]+x*beta[1]))

# %%
ndata=5000
mu=[0]
sig=[10]
beta=[-15*1/2,1/2]

x=stats.norm.rvs(loc=mu[0],scale=sig[0],size=ndata)
y=stats.bernoulli.rvs(p=logist(x,beta)).astype(int)

# %%
fig,ax=plt.subplots(figsize=[20,10])

# generate some data
#for j in range(ndata)
ind=np.arange(ndata)
plt.plot(ind[y==0],x[y==0],'o',markersize=10)
plt.plot(ind[y==1],x[y==1],'o',markersize=10)

# %%
fig,ax=plt.subplots(figsize=[20,10])
plt.plot(x,y,'o')

# %%
z=stats.binned_statistic(x,y,statistic='mean', bins=50)

# %%
fig,ax=plt.subplots(figsize=[20,10])
plt.plot(x,y,'o')
plt.vlines(z.bin_edges,0,1,linestyle='--',color=[0.8,0.8,0.8])

# %%
bin_centers=0.5*(z.bin_edges[1:]+z.bin_edges[:-1])
plt.plot(bin_centers,z.statistic,'o')

# %%
`
